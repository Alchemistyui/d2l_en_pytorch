# %% [markdown]
# ## 2.4.1 Derivatives and Differentiation

# %%
# from IPython import display
from matplotlib import pyplot as plt
import numpy as np

# %%
def f(x):
    return 3*x**2 - 4*x

def derivative_f(x, h):
    return (f(x+h) - f(x)) / h

h = 0.1
for i in range(5):
    print(h, derivative_f(1, h))
    h *= 0.001
# Out:
# 0.1 2.3000000000000043
# 0.0001 2.0002999999979565
# 1.0000000000000001e-07 2.000000298707505
# 1.0000000000000002e-10 2.0000001654807416
# 1.0000000000000002e-13 1.9984014443252816

# %% [markdown]
# ### Matplotlib Visualization

# %%
# display.set_matplotlib_formats('svg')
# plt.size(3.5, 2.5)
x = np.arange(0, 3, 0.1)
plt.figure(figsize=[5,4])
plt.plot(x, f(x), label='f(x)')
plt.plot(x, 2*x-3, 'r--', label='slope')

# Add the legend
plt.legend()

plt.xlabel('x')
plt.ylabel('y')
plt.title('function graph')

plt.grid(True)
# plt.axis([-1,3, -1,10])


plt.show()

# %%
# !pip install matplotlib

# %% [markdown]
# ## Exercise

# %%
# 1
def func(x):
    return x ** 3 - 1/x

x = np.arange(0.1,3, 0.1)


plt.figure(figsize=[5,5])


plt.plot(x, func(x), label='function')
plt.plot(x, 2*x-2, 'r--', label='tangent line')

plt.legend()

plt.title('exercise 1')
# plt.xlabel('x')
plt.ylabel('f(x)')

plt.grid(True)

plt.show()
